# %% [markdown]
# # Saving and loading
#
# Get the necessary files for the next session from https://www.kaggle.com/datasets/zalando-research/fashionmnist

# %% [markdown]
# ## Preparing the data

# %%
import pandas as pd
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import InputLayer
from tensorflow.keras.optimizers import SGD
print(f"Tensorflow version {tf.__version__}")

#read data with pandas
dataTrain = pd.read_csv('data/fashion-mnist_train.csv')
dataTest = pd.read_csv('data/fashion-mnist_test.csv')
#convert to numpy and initialize variables for training
X_train, y_train = dataTrain.iloc[:, 1:].to_numpy(), dataTrain.iloc[:, 0].to_numpy()
X_test, y_test = dataTest.iloc[:, 1:].to_numpy(), dataTest.iloc[:, 0].to_numpy()

#Define Classnames
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# prepare ground truth as one-hot encoded values
y_one_hot = tf.one_hot(y_train,len(class_names))
y_one_hot_test = tf.one_hot(y_test,len(class_names))
# Out:
# Tensorflow version 2.21.0

# %% [markdown]
# # Train a model

# %%
model = Sequential([
      InputLayer((784,)),
      Dense(512, activation='relu'),
      Dense(512, activation='relu'),
      Dense(10, activation="softmax")
      ])
model.compile(optimizer=SGD(learning_rate=0.001), loss="categorical_crossentropy", metrics=['accuracy'])
model.fit(
    X_train[0:10000],
    y_one_hot[0:10000],
    epochs=10,
    batch_size=100)

print("-----")
print("Evaluation on Training Data")
print(model.evaluate(X_test, y_one_hot_test, batch_size=1000))
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6284 - loss: 23.4933
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7242 - loss: 1.1797
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7623 - loss: 0.8281
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7855 - loss: 0.6529
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8081 - loss: 0.5639
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8265 - loss: 0.4857
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8405 - loss: 0.4428
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8555 - loss: 0.4035
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8618 - loss: 0.3733
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8724 - loss: 0.3472
# -----
# Evaluation on Training Data
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7777 - loss: 1.0002
# [1.0002275705337524, 0.7777000069618225]

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 512)                 │         401,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 669,708 (2.55 MB)
#  Trainable params: 669,706 (2.55 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# # Saving & Loading just the weights

# %%
# The following craete a savedirectory if not yet available
# !mkdir testmodel
# !dir
# Out:
# Ein Unterverzeichnis oder eine Datei mit dem Namen "testmodel" existiert bereits.
#  Volume in Laufwerk C: hat keine Bezeichnung.
#  Volumeseriennummer: D86A-A27D
#
#  Verzeichnis von c:\THWS\2026_SoSe_DeepLearning\jupytergit\_Lecture06
#
# 07.05.2026  14:12    <DIR>          .
# 07.05.2026  09:59    <DIR>          ..
# 07.05.2026  14:10    <DIR>          .ipynb_checkpoints
# 07.05.2026  09:59    <DIR>          data
# 07.05.2026  12:41            11.599 DL_008_Covenience.ipynb
# 07.05.2026  13:11             5.394 DL_009_TensorboardVsLivelossplot.ipynb
# 07.05.2026  13:23             9.221 DL_010_Regularization.ipynb
# 07.05.2026  14:12            18.660 DL_011_FashionMnist-SaveAndLoad.ipynb
# 07.05.2026  12:48    <DIR>          log
# 07.05.2026  09:59    <DIR>          testmodel
#                4 Datei(en),         44.874 Bytes
#                6 Verzeichnis(se), 522.275.512.320 Bytes frei

# %%
model.save_weights("testmodel/model1.weights.h5") # for tensorflow 2.16

# %%
# !dir testmodel
# Out:
#  Volume in Laufwerk C: hat keine Bezeichnung.
#  Volumeseriennummer: D86A-A27D
#
#  Verzeichnis von c:\THWS\2026_SoSe_DeepLearning\jupytergit\_Lecture06\testmodel
#
# 07.05.2026  14:18    <DIR>          .
# 07.05.2026  14:12    <DIR>          ..
# 07.05.2026  14:18         2.698.760 model1.weights.h5
#                1 Datei(en),      2.698.760 Bytes
#                2 Verzeichnis(se), 522.265.260.032 Bytes frei

# %%
# recreate the network
model2 = Sequential([
      InputLayer((784,)),
      Dense(512, activation='relu'),
      Dense(512, activation='relu'),
      Dense(10, activation="softmax")
      ])
#model2.load_weights("testmodel/model1")
model2.load_weights("testmodel/model1.weights.h5")
model2.compile(optimizer=SGD(learning_rate=0.001), loss="categorical_crossentropy", metrics=['accuracy'])

# %%
print("Evaluation on Test Data")
print(model2.evaluate(X_test, y_one_hot_test, batch_size=1000))
# Out:
# Evaluation on Test Data
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7777 - loss: 1.0002
# [1.0002275705337524, 0.7777000069618225]

# %% [markdown]
# # Saving & Loading the complete model

# %%
model.save("testmodel/model2.keras")

# %%
from tensorflow import keras
model3 = keras.models.load_model('testmodel/model2.keras')
model3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 512)                 │         401,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 669,708 (2.55 MB)
#  Trainable params: 669,706 (2.55 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
print("Evaluation on Test Data")
print(model2.evaluate(X_test, y_one_hot_test, batch_size=1000))
# Out:
# Evaluation on Test Data
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7777 - loss: 1.0002
# [1.0002275705337524, 0.7777000069618225]

# %%
import keras
import torch
import os

os.environ["KERAS_BACKEND"] = "torch"
# Load the .keras model
model = keras.models.load_model("testmodel/model2.keras")
type(model)
# Out:
# keras.src.models.sequential.Sequential

# %% [markdown]
# # Saving continuously during training
#
# ModelCheckpoints help to regularily save the model during training. This is good on cloud environments like google colab, when your model could be unexpectedly stopped to not loose already gained progress.
#
# https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint

# %%
model2 = Sequential([
      InputLayer((784,)),
      Dense(512, activation='relu'),
      Dense(512, activation='relu'),
      Dense(10, activation="softmax")
      ])
model.compile(
    optimizer=SGD(learning_rate=0.001), 
    loss="sparse_categorical_crossentropy", 
    metrics=['accuracy'])

from tensorflow.keras.callbacks import ModelCheckpoint;
cp_callback = ModelCheckpoint(filepath="testmodel/training.weights.h5",
                              save_weights_only=True,
                              verbose=1)

model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=100,
    callbacks=[cp_callback])

# %%
model3.load_weights("testmodel/training.weights.h5")
