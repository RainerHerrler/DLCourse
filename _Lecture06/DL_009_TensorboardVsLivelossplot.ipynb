# %% [markdown]
# #  Tensorboard and Livelossplot
#
# In this notebook we learn about how to observe the trainingprocess. Please install tensorboard in your environment and start it before running this  notebook

# %% [markdown]
# ## Preparing the data (Fashion MNist)

# %%
import pandas as pd
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
print(f"Tesorflow version {tf.__version__}")

#read data with pandas
dataTrain = pd.read_csv('data/fashion-mnist_train.csv')
dataTest = pd.read_csv('data/fashion-mnist_test.csv')

#convert to numpy and initialize variables for training
X_train, y_train = dataTrain.iloc[:, 1:].to_numpy(), dataTrain.iloc[:, 0].to_numpy()
X_test, y_test = dataTest.iloc[:, 1:].to_numpy(), dataTest.iloc[:, 0].to_numpy()

#Define Classnames
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# prepare ground truth as one-hot encoded values
y_one_hot = tf.one_hot(y_train,len(class_names))
y_one_hot_test = tf.one_hot(y_test,len(class_names))


print("Fashion Mnist")
print(f"Training data size: {X_train.shape}")
print(f"Test data size:     {X_test.shape}")
print(f"One Hot encoded:    {y_one_hot.shape}")

# %% [markdown]
# # Tensorboard
#
# TensorBoard is a visualization tool that helps you monitor neural network training by showing things like loss curves, accuracy, learning rate, model graphs, and embeddings. It is useful because it makes debugging and understanding training much easier — for example, you can quickly see if a model is overfitting or if the loss stops improving. Although TensorBoard was originally created for TensorFlow, it also works very well with PyTorch through torch.utils.tensorboard

# %%
# excute this on the command line:
# conda activate DL # activate your Environmnet
# cd [yourgitdir]/_lecture6
# pip install tensorboard
# tensorboard --logdir log

# %%
# this runs for a 100 epochs, if needed interrupt it with ESC-i-i
model = Sequential([
      Dense(100, activation='sigmoid'),
      Dense(10, activation="softmax")
      ])
model.compile(optimizer='sgd', loss="categorical_crossentropy", metrics=['accuracy'])

# We need to create this to write the data to disc
tensorboard_callback = tf.keras.callbacks.TensorBoard("log", histogram_freq=1)

model.fit(
    X_train,
    y_one_hot,
    epochs=1000,
    batch_size=100,
    validation_data=(X_test, y_one_hot_test),
    callbacks=[tensorboard_callback])

# %%
model.summary()

# %% [markdown]
# # Livelossplot

# %%
#pip install livelossplot

# %%
from livelossplot import PlotLossesKeras

model = Sequential([
      Dense(100, activation='sigmoid'),
      Dense(10, activation="softmax")
      ])
model.compile(optimizer='sgd', loss="categorical_crossentropy", metrics=['accuracy'])

plotlosses = PlotLossesKeras()
model.fit(
    X_train,
    y_one_hot,
    epochs=1000,
    batch_size=100,
    validation_data=(X_test,y_one_hot_test),
    callbacks=[plotlosses])
